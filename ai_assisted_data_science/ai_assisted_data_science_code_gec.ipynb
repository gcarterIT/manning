# %%
# Listing 5.1 Listing available OpenAI models

import openai  # Import OpenAI Python library

openai.api_key = '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' # Set OpenAI access key (replace dots)

models = client.models.list() # Get available OpenAI models

print(models) # Print out retrieved model
# Out:
# SyncPage[Model](data=[Model(id='gpt-3.5-turbo-1106', created=1698959748, object='model', owned_by='system'), Model(id='dall-e-3', created=1698785189, object='model', owned_by='system'), Model(id='gpt-4-0613', created=1686588896, object='model', owned_by='openai'), Model(id='dall-e-2', created=1698798177, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-0125', created=1706048358, object='model', owned_by='system'), Model(id='gpt-4', created=1687882411, object='model', owned_by='openai'), Model(id='whisper-1', created=1677532384, object='model', owned_by='openai-internal'), Model(id='tts-1-hd-1106', created=1699053533, object='model', owned_by='system'), Model(id='tts-1-hd', created=1699046015, object='model', owned_by='system'), Model(id='text-embedding-3-large', created=1705953180, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-0301', created=1677649963, object='model', owned_by='openai'), Model(id='gpt-3.5-turbo-0613', created=1686587434, object='model', owne
# ...

# %%
from openai import OpenAI

# Modify OpenAI's API key and API base to use vLLM's API server.
openai_api_key = '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'
openai_api_base = 'https://api.openai.com/v1'

client = OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
    api_key=openai_api_key,
    base_url=openai_api_base,
)

models = client.models.list()

print(models)
# Out:
# SyncPage[Model](data=[Model(id='gpt-3.5-turbo-1106', created=1698959748, object='model', owned_by='system'), Model(id='dall-e-3', created=1698785189, object='model', owned_by='system'), Model(id='gpt-4-0613', created=1686588896, object='model', owned_by='openai'), Model(id='dall-e-2', created=1698798177, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-0125', created=1706048358, object='model', owned_by='system'), Model(id='gpt-4', created=1687882411, object='model', owned_by='openai'), Model(id='whisper-1', created=1677532384, object='model', owned_by='openai-internal'), Model(id='tts-1-hd-1106', created=1699053533, object='model', owned_by='system'), Model(id='tts-1-hd', created=1699046015, object='model', owned_by='system'), Model(id='text-embedding-3-large', created=1705953180, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-0301', created=1677649963, object='model', owned_by='openai'), Model(id='gpt-3.5-turbo-0613', created=1686587434, object='model', owne
# ...

# %%
# Listing 5.3 Using GPT for text completion

#import openai b Import OpenAI Python library
#openai.api_key = '...' c Set OpenAI access key (replace dots)

result = openai.Completion.create(

# model='text-davinci-003',
# 'The model `text-davinci-003` has been deprecated,
    
prompt='Tell me a story!') # Use GPT model for completion
print(result)
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[9], line 6
#       1 # Listing 5.3 Using GPT for text completion
#       2
#       3 #import openai b Import OpenAI Python library
#       4 #openai.api_key = '...' c Set OpenAI access key (replace dots)
# ----> 6 result = openai.Completion.create(
#       7 model='text-davinci-003',
#       8 prompt='Tell me a story!') # Use GPT model for completion
#       9 print(result)
#
# File C:\Program Files\Python311\Lib\site-packages\openai\lib\_old_api.py:39, in APIRemovedInV1Proxy.__call__(self, *_args, **_kwargs)
#      38 def __call__(self, *_args: Any, **_kwargs: Any) -> Any:
# ---> 39     raise APIRemovedInV1(symbol=self._symbol)
#
# APIRemovedInV1:
#
# You tried to access openai.Completion, but this is no longer supported in openai>=1.0.0 - see the README at https://github.com/openai/openai-python for the API.
#
# ...

# %%
from openai import OpenAI

# Modify OpenAI's API key and API base to use vLLM's API server.
openai_api_key = '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'
openai_api_base = 'https://api.openai.com/v1'

client = OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
    api_key=openai_api_key,
    base_url=openai_api_base,
)

result = client.completions.create(
model='davinci-002',
prompt='Tell me a story!') # Use GPT model for completion
print(result)
# Out:
# Completion(id='cmpl-96rRHgL874pfG8QTPkx9e1Sr6ARkY', choices=[CompletionChoice(finish_reason='length', index=0, logprobs=None, text=' About writers and their creative journey through the archives.\n\nSunday 15 April, ')], created=1711422415, model='davinci-002', object='text_completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=16, prompt_tokens=5, total_tokens=21))

# %%
# DataScienceWithGPT/src/chapter5/listing1.py
# -------------------------------------------
# ORIGINAL 
# --------
import openai
openai_api_key = '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'
models = openai.Model.list()
print(models)

# Outpur (error): You tried to access openai.Model, but this is no longer supported in openai>=1.0.0 ...

# %%
# DataScienceWithGPT/src/chapter5/listing1.py
# -------------------------------------------
# REVISION 
# --------
import openai
openai_api_key = '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'
openai_api_base = 'https://api.openai.com/v1'

client = OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
    api_key=openai_api_key,
    base_url=openai_api_base,
)
models = client.models.list()
print(models)

# Output: SyncPage[Model](data=[Model(id='gpt-3.5-turbo-1106', created=1698959748, object='model', 
#        owned_by='system'), Model(id='dall-e-3', created=1698785189, object='model', owned_by='system'), 
#        Model(id='gpt-4-0613', created=1686588896, object='model', owned_by='openai'), Model(id='dall-e-2', 
#        created=1698798177, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-0125', ...
# Out:
# SyncPage[Model](data=[Model(id='gpt-3.5-turbo-1106', created=1698959748, object='model', owned_by='system'), Model(id='dall-e-3', created=1698785189, object='model', owned_by='system'), Model(id='gpt-4-0613', created=1686588896, object='model', owned_by='openai'), Model(id='dall-e-2', created=1698798177, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-0125', created=1706048358, object='model', owned_by='system'), Model(id='gpt-4', created=1687882411, object='model', owned_by='openai'), Model(id='whisper-1', created=1677532384, object='model', owned_by='openai-internal'), Model(id='tts-1-hd-1106', created=1699053533, object='model', owned_by='system'), Model(id='tts-1-hd', created=1699046015, object='model', owned_by='system'), Model(id='text-embedding-3-large', created=1705953180, object='model', owned_by='system'), Model(id='gpt-3.5-turbo-0301', created=1677649963, object='model', owned_by='openai'), Model(id='gpt-3.5-turbo-0613', created=1686587434, object='model', owne
# ...

# %%
# DataScienceWithGPT/src/chapter5/listing3.py
# -------------------------------------------
# ORIGINAL 
# --------
import openai
openai_api_key = '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'
result = openai.Completion.create(
    model='text-davinci-003', 
    prompt='Tell me a story!')
print(result)

# Outpur (error): You tried to access openai.Completion, but this is no longer supported in openai>=1.0.0 - ...

# %%
# DataScienceWithGPT/src/chapter5/listing3.py
# -------------------------------------------
# REVISION 
# --------
import openai
openai_api_key = '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'
openai_api_base = 'https://api.openai.com/v1'

client = OpenAI(
    # defaults to os.environ.get("OPENAI_API_KEY")
    api_key=openai_api_key,
    base_url=openai_api_base,
)

result = client.completions.create(
model='davinci-002',
prompt='Tell me a story!') # Use GPT model for completion
print(result) 

# OUTPUT: Completion(id='cmpl-974GKqHW5TygptKdZmJbaTEB5ysJw', choices=[CompletionChoice(finish_reason='length', 
#         index=0, logprobs=None, text=' An adventure tale for elementary. 32 infamous capitals voted as stupidest ideas in')], 
#         created=1711471708, model='davinci-002', object='text_completion', system_fingerprint=None, 
#         usage=CompletionUsage(completion_tokens=16, prompt_tokens=5, total_tokens=21))
# Out:
# Completion(id='cmpl-974GKqHW5TygptKdZmJbaTEB5ysJw', choices=[CompletionChoice(finish_reason='length', index=0, logprobs=None, text=' An adventure tale for elementary. 32 infamous capitals voted as stupidest ideas in')], created=1711471708, model='davinci-002', object='text_completion', system_fingerprint=None, usage=CompletionUsage(completion_tokens=16, prompt_tokens=5, total_tokens=21))
