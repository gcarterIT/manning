# %%
pip install requests_html
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yahoo_fin
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
# ...
#   Using cached websockets-10.4-cp312-cp312-win_amd64.whl
# ...
# Using cached urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
# ...
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6060 sha256=ec55b3241c2ca1e2ff7e1acc70e316872d63d76b77d22bc261ccafff2b05f4ac
#   Stored in directory: c:\users\gcart\appdata\local\pip\cache\wheels\03\f5\1a\23761066dac1d0e8e683e5fdb27e12de53209d05a4a37e6246
# Successfully built sgmllib3k
# ...
#   Attempting uninstall: websockets
#     Found existing installation: websockets 15.0.1
#     Uninstalling websockets-15.0.1:
#       Successfully uninstalled websockets-15.0.1
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ...

# %%
from yahoo_fin import stock_info as si

# download data for AMZN
amzn_data = si.get_data("AMZN")

# show the first few result records
amzn_data.head()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     977 try:
# --> 978     return complexjson.loads(self.text, **kwargs)
#     979 except JSONDecodeError as e:
#     980     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     981     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~\anaconda3\Lib\site-packages\simplejson\__init__.py:514, in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, allow_nan, **kw)
#     510 if (cls is None and encoding is None and object_hook is None and
#     511         parse_int is None and parse_float is None and
#     512         parse_constant is None and object_pairs_hook is None
#     513         and not use_decimal and not allow_nan and not kw):
# ...
