# %%
pip install openai

# %%
import openai
openai.organization = "org-uypVdr4x9b8cfQ9mSfiEQVNu"
openai.api_key = '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'
models = openai.Model.list()
print(models)
# Out:
# {
#   "object": "list",
#   "data": [
#     {
#       "id": "text-davinci-001",
#       "object": "model",
#       "created": 1649364042,
#       "owned_by": "openai",
#       "permission": [
#         {
#           "id": "modelperm-CDlahk1RbkghXDjtxqzXoPNo",
#           "object": "model_permission",
#           "created": 1690913868,
#           "allow_create_engine": false,
#           "allow_sampling": true,
#           "allow_logprobs": true,
#           "allow_search_indices": false,
#           "allow_view": true,
#           "allow_fine_tuning": false,
#           "organization": "*",
#           "group": null,
#           "is_blocking": false
#         }
#       ],
#       "root": "text-davinci-001",
#       "parent": null
#     },
#     {
#       "id": "text-search-curie-query-001",
#       "object": "model",
#       "created": 1651172509,
#       "owned_by": "openai-dev",
#       "permission": [
#         {
#           "id": "modelperm-fNgpMH6ZEQulSq1CjzlfQuIe",
# ...

# %%
# https://stackoverflow.com/questions/75773786/cant-access-gpt-4-model-via-python-api-although-gpt-3-5-works

# Author: Viet Dac Lai
import pprint

#openai.organization = "org-uypVdr4x9b8cfQ9mSfiEQVNu"
#openai.api_key = "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"

GPT4 = 'gpt-4-0314'
MODEL_NAME = GPT4
model = openai.Model(MODEL_NAME)

def list_all_models():
    model_list = openai.Model.list()['data']
    model_ids = [x['id'] for x in model_list]
    model_ids.sort()
    pprint.pprint(model_ids)

if __name__ == '__main__':
    list_all_models()
# Out:
# ['ada',
#  'ada-code-search-code',
#  'ada-code-search-text',
#  'ada-search-document',
#  'ada-search-query',
#  'ada-similarity',
#  'babbage',
#  'babbage-code-search-code',
#  'babbage-code-search-text',
#  'babbage-search-document',
#  'babbage-search-query',
#  'babbage-similarity',
#  'code-davinci-edit-001',
#  'code-search-ada-code-001',
#  'code-search-ada-text-001',
#  'code-search-babbage-code-001',
#  'code-search-babbage-text-001',
#  'curie',
#  'curie-instruct-beta',
#  'curie-search-document',
#  'curie-search-query',
#  'curie-similarity',
#  'davinci',
#  'davinci-instruct-beta',
#  'davinci-search-document',
#  'davinci-search-query',
#  'davinci-similarity',
#  'gpt-3.5-turbo',
#  'gpt-3.5-turbo-0301',
#  'gpt-3.5-turbo-0613',
#  'gpt-3.5-turbo-16k',
#  'gpt-3.5-turbo-16k-0613',
#  'text-ada-001',
#  'text-babbage-001',
#  'text-curie-001',
#  'text-davinci-001',
#  'text-davinci-002',
#  'text-davinci-003',
#  'text-davinci-edit-001',
# ...

# %%
import openai
openai.organization = "org-uypVdr4x9b8cfQ9mSfiEQVNu"
openai.api_key = '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'

result = openai.Completion.create(
  model='text-davinci-003',
  #model="gpt-4",
  prompt='Tell me a story!')
print(result)
# Out:
# {
#   "warning": "This model version is deprecated. Migrate before January 4, 2024 to avoid disruption of service. Learn more https://platform.openai.com/docs/deprecations",
#   "id": "cmpl-7iuvWYnpzMCWYVM5OZDafDPyVLe3i",
#   "object": "text_completion",
#   "created": 1690939614,
#   "model": "text-davinci-003",
#   "choices": [
#     {
#       "text": "\n\nOnce upon a time, there was a young boy named Jack who lived",
#       "index": 0,
#       "logprobs": null,
#       "finish_reason": "length"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 5,
#     "completion_tokens": 16,
#     "total_tokens": 21
#   }
# }

# %%
prompt = "Hello"
model = "text-davinci-003"
response = openai.Completion.create(engine=model, prompt=prompt, max_tokens=50)

generated_text = response.choices[0].text
print(generated_text)
# Out:
# World
#
# Hello world!
